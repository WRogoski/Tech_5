# %% [markdown]
# <a href="https://colab.research.google.com/github/WRogoski/Tech_5/blob/main/PassosMagicos_grupo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

base_original = 'https://raw.githubusercontent.com/WRogoski/Tech_5/main/PEDE_PASSOS_DATASET_FIAP.csv'
pd.set_option('display.max_columns', None)
df = pd.read_csv(base_original, delimiter=';')

# %% [markdown]
# ###EDA

# %%
df.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 1                           NaN  ALUNO-2              NaN          NaN
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020              INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não              7.883.752                  B
# 1             NaN               NaN                    NaN                NaN
# 2              3H               Não  7.856.389.666.666.660                  B
# 3              1D               Não              5.076.252                  D
# 4              2M               Não              8.077.085                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 69 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   INSTITUICAO_ENSINO_ALUNO_2020  728 non-null    object
#  1   NOME                           1349 non-null   object
#  2   IDADE_ALUNO_2020               728 non-null    object
#  3   ANOS_PM_2020                   728 non-null    object
#  4   FASE_TURMA_2020                728 non-null    object
#  5   PONTO_VIRADA_2020              702 non-null    object
#  6   INDE_2020                      728 non-null    object
#  7   INDE_CONCEITO_2020             728 non-null    object
#  8   PEDRA_2020                     728 non-null    object
#  9   DESTAQUE_IEG_2020              728 non-null    object
#  10  DESTAQUE_IDA_2020              728 non-null    object
#  11  DESTAQUE_IPV_2020              703 non-null    object
# ...

# %%
df.columns[df.columns.str.contains('2020')]
# Out:
# Index(['INSTITUICAO_ENSINO_ALUNO_2020', 'IDADE_ALUNO_2020', 'ANOS_PM_2020',
#        'FASE_TURMA_2020', 'PONTO_VIRADA_2020', 'INDE_2020',
#        'INDE_CONCEITO_2020', 'PEDRA_2020', 'DESTAQUE_IEG_2020',
#        'DESTAQUE_IDA_2020', 'DESTAQUE_IPV_2020', 'IAA_2020', 'IEG_2020',
#        'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020'],
#       dtype='object')

# %%
df.columns[df.columns.str.contains('2021')]
# Out:
# Index(['FASE_2021', 'TURMA_2021', 'INSTITUICAO_ENSINO_ALUNO_2021',
#        'SINALIZADOR_INGRESSANTE_2021', 'PEDRA_2021', 'INDE_2021', 'IAA_2021',
#        'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'REC_EQUIPE_1_2021',
#        'REC_EQUIPE_2_2021', 'REC_EQUIPE_3_2021', 'REC_EQUIPE_4_2021',
#        'PONTO_VIRADA_2021', 'IPV_2021', 'IAN_2021', 'NIVEL_IDEAL_2021',
#        'DEFASAGEM_2021'],
#       dtype='object')

# %%
df.columns[df.columns.str.contains('2022')]
# Out:
# Index(['FASE_2022', 'TURMA_2022', 'ANO_INGRESSO_2022', 'BOLSISTA_2022',
#        'INDE_2022', 'CG_2022', 'CF_2022', 'CT_2022', 'PEDRA_2022',
#        'DESTAQUE_IEG_2022', 'DESTAQUE_IDA_2022', 'DESTAQUE_IPV_2022',
#        'IAA_2022', 'IEG_2022', 'IPS_2022', 'IDA_2022', 'NOTA_PORT_2022',
#        'NOTA_MAT_2022', 'NOTA_ING_2022', 'QTD_AVAL_2022', 'IPP_2022',
#        'REC_AVA_1_2022', 'REC_AVA_2_2022', 'REC_AVA_3_2022', 'REC_AVA_4_2022',
#        'INDICADO_BOLSA_2022', 'PONTO_VIRADA_2022', 'IPV_2022', 'IAN_2022',
#        'NIVEL_IDEAL_2022'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['INSTITUICAO_ENSINO_ALUNO_2020', 'NOME', 'IDADE_ALUNO_2020',
#        'ANOS_PM_2020', 'FASE_TURMA_2020', 'PONTO_VIRADA_2020', 'INDE_2020',
#        'INDE_CONCEITO_2020', 'PEDRA_2020', 'DESTAQUE_IEG_2020',
#        'DESTAQUE_IDA_2020', 'DESTAQUE_IPV_2020', 'IAA_2020', 'IEG_2020',
#        'IPS_2020', 'IDA_2020', 'IPP_2020', 'IPV_2020', 'IAN_2020', 'FASE_2021',
#        'TURMA_2021', 'INSTITUICAO_ENSINO_ALUNO_2021',
#        'SINALIZADOR_INGRESSANTE_2021', 'PEDRA_2021', 'INDE_2021', 'IAA_2021',
#        'IEG_2021', 'IPS_2021', 'IDA_2021', 'IPP_2021', 'REC_EQUIPE_1_2021',
#        'REC_EQUIPE_2_2021', 'REC_EQUIPE_3_2021', 'REC_EQUIPE_4_2021',
#        'PONTO_VIRADA_2021', 'IPV_2021', 'IAN_2021', 'NIVEL_IDEAL_2021',
#        'DEFASAGEM_2021', 'FASE_2022', 'TURMA_2022', 'ANO_INGRESSO_2022',
#        'BOLSISTA_2022', 'INDE_2022', 'CG_2022', 'CF_2022', 'CT_2022',
#        'PEDRA_2022', 'DESTAQUE_IEG_2022', 'DESTAQUE_IDA_2022',
# ...

# %% [markdown]
# ###Ajustando DF

# %%
df_2 = df[['NOME', 'ANOS_PM_2020', 'FASE_TURMA_2020', 'FASE_2021', 'FASE_2022', 'IAA_2020', 'IAA_2021', 'IAA_2022', 'IAN_2020', 'IAN_2021', 'IAN_2022', 'IDA_2020', 'IDA_2021', 'IDA_2022', 'IEG_2020', 'IEG_2021', 'IEG_2022', 'INDE_2020', 'INDE_2021', 'INDE_2022', 'IPP_2020', 'IPP_2021', 'IPP_2022', 'IPS_2020', 'IPS_2021', 'IPS_2022', 'IPV_2020', 'IPV_2021', 'IPV_2022', 'PEDRA_2020', 'PEDRA_2021', 'PEDRA_2022', 'PONTO_VIRADA_2020', 'PONTO_VIRADA_2021', 'PONTO_VIRADA_2022']]


df_2.head()
# Out:
#       NOME ANOS_PM_2020 FASE_TURMA_2020  FASE_2021  FASE_2022  \
# 0  ALUNO-1            2              2H        2.0        NaN
# 1  ALUNO-2          NaN             NaN        NaN        0.0
# 2  ALUNO-3            2              3H        3.0        NaN
# 3  ALUNO-4            2              1D        NaN        2.0
# 4  ALUNO-5            1              2M        2.0        2.0
#
#                 IAA_2020  IAA_2021   IAA_2022 IAN_2020  IAN_2021  IAN_2022  \
# 0  8.500.020.000.000.000       7.5        NaN       10       5.0       NaN
# 1                    NaN       NaN  1.000.002      NaN       NaN       5.0
# 2                791.667       7.1        NaN       10      10.0       NaN
# 3  8.000.020.000.000.000       NaN  1.000.002        5       NaN       5.0
# 4                750.002       7.4    641.668       10      10.0       5.0
#
#   IDA_2020  IDA_2021               IDA_2022 IEG_2020  IEG_2021  \
# 0        7       8.8                    NaN      8.7       6.3
# ...

# %%
base_alunos = 'https://raw.githubusercontent.com/WRogoski/Tech_5/main/TbAluno.csv'
bd_alunos = pd.read_csv(base_alunos)
bd_alunos.head()
# Out:
#    IdAluno NomeAluno  NomeAbreviado  IdUnidade Sexo  EstadoCivil  \
# 0        3   Aluno 1            NaN        1.0    F          5.0
# 1        4   Aluno 2            NaN        1.0    F          5.0
# 2        5   Aluno 3            NaN        1.0    F          5.0
# 3        6   Aluno 4            NaN        1.0    M          5.0
# 4        7   Aluno 5            NaN        1.0    M          5.0
#
#         DataNascimento  IdPai IdMae  IdResponsavel  IdTipoResponsavel  \
# 0  2005-03-29 03:00:00    NaN     5            5.0                 11
# 1  2004-11-04 02:00:00    6.0   NaN            6.0                 11
# 2  2002-01-25 02:00:00    NaN   NaN            7.0                 11
# 3  2002-10-07 03:00:00    NaN     8            8.0                 11
# 4  2002-12-23 02:00:00    NaN     9            9.0                 11
#
#   Naturalidade Nacionalidade  TipoSangue  PlanoSaude  Alergia  Medicamento  \
# ...

# %%
bd_alunos['NomeAluno'] = bd_alunos['NomeAluno'].str.replace('Aluno ', 'ALUNO-', regex=False)
bd_alunos.head()
# Out:
#    IdAluno NomeAluno  NomeAbreviado  IdUnidade Sexo  EstadoCivil  \
# 0        3   ALUNO-1            NaN        1.0    F          5.0
# 1        4   ALUNO-2            NaN        1.0    F          5.0
# 2        5   ALUNO-3            NaN        1.0    F          5.0
# 3        6   ALUNO-4            NaN        1.0    M          5.0
# 4        7   ALUNO-5            NaN        1.0    M          5.0
#
#         DataNascimento  IdPai IdMae  IdResponsavel  IdTipoResponsavel  \
# 0  2005-03-29 03:00:00    NaN     5            5.0                 11
# 1  2004-11-04 02:00:00    6.0   NaN            6.0                 11
# 2  2002-01-25 02:00:00    NaN   NaN            7.0                 11
# 3  2002-10-07 03:00:00    NaN     8            8.0                 11
# 4  2002-12-23 02:00:00    NaN     9            9.0                 11
#
#   Naturalidade Nacionalidade  TipoSangue  PlanoSaude  Alergia  Medicamento  \
# ...

# %%
bd_alunos_2 = bd_alunos[['NomeAluno', 'Sexo', 'DataNascimento', 'CorRaca']]
bd_alunos_2.head()
# Out:
#   NomeAluno Sexo       DataNascimento CorRaca
# 0   ALUNO-1    F  2005-03-29 03:00:00       R
# 1   ALUNO-2    F  2004-11-04 02:00:00       B
# 2   ALUNO-3    F  2002-01-25 02:00:00       B
# 3   ALUNO-4    M  2002-10-07 03:00:00       R
# 4   ALUNO-5    M  2002-12-23 02:00:00       R

# %%
bd_alunos_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NomeAluno       2238 non-null   object
#  1   Sexo            2237 non-null   object
#  2   DataNascimento  2238 non-null   object
#  3   CorRaca         2237 non-null   object
# dtypes: object(4)
# memory usage: 70.1+ KB

# %%
bd_alunos_2.rename(columns={'NomeAluno': 'NOME'}, inplace=True)
# Out:
# <ipython-input-12-3adf89481538>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd_alunos_2.rename(columns={'NomeAluno': 'NOME'}, inplace=True)

# %%
bd_alunos_2.head()
# Out:
#       NOME Sexo       DataNascimento CorRaca
# 0  ALUNO-1    F  2005-03-29 03:00:00       R
# 1  ALUNO-2    F  2004-11-04 02:00:00       B
# 2  ALUNO-3    F  2002-01-25 02:00:00       B
# 3  ALUNO-4    M  2002-10-07 03:00:00       R
# 4  ALUNO-5    M  2002-12-23 02:00:00       R

# %%
df_3 = pd.merge(df_2, bd_alunos_2, on='NOME')
df_3.head()
# Out:
#       NOME ANOS_PM_2020 FASE_TURMA_2020  FASE_2021  FASE_2022  \
# 0  ALUNO-1            2              2H        2.0        NaN
# 1  ALUNO-2          NaN             NaN        NaN        0.0
# 2  ALUNO-3            2              3H        3.0        NaN
# 3  ALUNO-4            2              1D        NaN        2.0
# 4  ALUNO-5            1              2M        2.0        2.0
#
#                 IAA_2020  IAA_2021   IAA_2022 IAN_2020  IAN_2021  IAN_2022  \
# 0  8.500.020.000.000.000       7.5        NaN       10       5.0       NaN
# 1                    NaN       NaN  1.000.002      NaN       NaN       5.0
# 2                791.667       7.1        NaN       10      10.0       NaN
# 3  8.000.020.000.000.000       NaN  1.000.002        5       NaN       5.0
# 4                750.002       7.4    641.668       10      10.0       5.0
#
#   IDA_2020  IDA_2021               IDA_2022 IEG_2020  IEG_2021  \
# 0        7       8.8                    NaN      8.7       6.3
# ...

# %%
df_3.shape
# Out:
# (1349, 38)

# %%
df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NOME               1349 non-null   object
#  1   ANOS_PM_2020       728 non-null    object
#  2   FASE_TURMA_2020    728 non-null    object
#  3   FASE_2021          686 non-null    float64
#  4   FASE_2022          862 non-null    float64
#  5   IAA_2020           728 non-null    object
#  6   IAA_2021           686 non-null    float64
#  7   IAA_2022           862 non-null    object
#  8   IAN_2020           728 non-null    object
#  9   IAN_2021           686 non-null    float64
#  10  IAN_2022           862 non-null    float64
#  11  IDA_2020           728 non-null    object
#  12  IDA_2021           686 non-null    float64
#  13  IDA_2022           862 non-null    object
#  14  IEG_2020           728 non-null    object
#  15  IEG_2021           686 non-null    float64
# ...

# %%
df_3['FASE_TURMA_2020'] = df_3['FASE_TURMA_2020'].str.extract('(\w)', expand=False)

df_3.head()
# Out:
#       NOME ANOS_PM_2020 FASE_TURMA_2020  FASE_2021  FASE_2022  \
# 0  ALUNO-1            2               2        2.0        NaN
# 1  ALUNO-2          NaN             NaN        NaN        0.0
# 2  ALUNO-3            2               3        3.0        NaN
# 3  ALUNO-4            2               1        NaN        2.0
# 4  ALUNO-5            1               2        2.0        2.0
#
#                 IAA_2020  IAA_2021   IAA_2022 IAN_2020  IAN_2021  IAN_2022  \
# 0  8.500.020.000.000.000       7.5        NaN       10       5.0       NaN
# 1                    NaN       NaN  1.000.002      NaN       NaN       5.0
# 2                791.667       7.1        NaN       10      10.0       NaN
# 3  8.000.020.000.000.000       NaN  1.000.002        5       NaN       5.0
# 4                750.002       7.4    641.668       10      10.0       5.0
#
#   IDA_2020  IDA_2021               IDA_2022 IEG_2020  IEG_2021  \
# 0        7       8.8                    NaN      8.7       6.3
# ...

# %%
converter = ['ANOS_PM_2020','FASE_TURMA_2020','IAA_2020','IAA_2022','IAN_2020','IDA_2020','IDA_2022','IEG_2020','IEG_2022','INDE_2020','INDE_2021','INDE_2022','IPP_2020','IPP_2022','IPS_2020','IPV_2020','IPV_2022']

# %%
for col in converter:
    try:
        df_3[col] = pd.to_numeric(df_3[col], errors='coerce')
    except:
        pass

# Verificando os tipos de dados após a conversão
print(df_3.dtypes)
# Out:
# NOME                  object
# ANOS_PM_2020         float64
# FASE_TURMA_2020      float64
# FASE_2021            float64
# FASE_2022            float64
# IAA_2020             float64
# IAA_2021             float64
# IAA_2022             float64
# IAN_2020             float64
# IAN_2021             float64
# IAN_2022             float64
# IDA_2020             float64
# IDA_2021             float64
# IDA_2022             float64
# IEG_2020             float64
# IEG_2021             float64
# IEG_2022             float64
# INDE_2020            float64
# INDE_2021            float64
# INDE_2022            float64
# IPP_2020             float64
# IPP_2021             float64
# IPP_2022             float64
# IPS_2020             float64
# IPS_2021             float64
# IPS_2022             float64
# IPV_2020             float64
# IPV_2021             float64
# IPV_2022             float64
# PEDRA_2020            object
# PEDRA_2021            object
# PEDRA_2022            object
# ...

# %%
df_3['DataNascimento'] = pd.to_datetime(df_3['DataNascimento'], errors='coerce')
df_3['DataNascimento'] = df_3['DataNascimento'].dt.strftime('%d/%m/%Y')
df_3.head()
# Out:
#       NOME  ANOS_PM_2020  FASE_TURMA_2020  FASE_2021  FASE_2022  IAA_2020  \
# 0  ALUNO-1           2.0              2.0        2.0        NaN       NaN
# 1  ALUNO-2           NaN              NaN        NaN        0.0       NaN
# 2  ALUNO-3           2.0              3.0        3.0        NaN   791.667
# 3  ALUNO-4           2.0              1.0        NaN        2.0       NaN
# 4  ALUNO-5           1.0              2.0        2.0        2.0   750.002
#
#    IAA_2021  IAA_2022  IAN_2020  IAN_2021  IAN_2022  IDA_2020  IDA_2021  \
# 0       7.5       NaN      10.0       5.0       NaN       7.0       8.8
# 1       NaN       NaN       NaN       NaN       5.0       NaN       NaN
# 2       7.1       NaN      10.0      10.0       NaN       5.5       5.6
# 3       NaN       NaN       5.0       NaN       5.0       0.0       NaN
# 4       7.4   641.668      10.0      10.0       5.0       7.5       5.4
#
#    IDA_2022  IEG_2020  IEG_2021  IEG_2022  INDE_2020  INDE_2021  INDE_2022  \
# ...

# %% [markdown]
# # **CÁLCULO INDE**

# %%
df_3['INDE_CALCULADO_2020'] = np.where(
    df_3['FASE_TURMA_2020'] < 8,
    df_3['IAN_2020']*0.1 + df_3['IDA_2020']*0.2 + df_3['IEG_2020']*0.2 + df_3['IAA_2020']*0.1 + df_3['IPS_2020']*0.1 + df_3['IPP_2020']*0.1 + df_3['IPV_2020']*0.2,
    df_3['IAN_2020']*0.1 + df_3['IDA_2020']*0.4 + df_3['IEG_2020']*0.2 + df_3['IAA_2020']*0.1 + df_3['IPS_2020']*0.2
)

df_3['INDE_CALCULADO_2021'] = np.where(
    df_3['FASE_2021'] < 8,
    df_3['IAN_2021']*0.1 + df_3['IDA_2021']*0.2 + df_3['IEG_2021']*0.2 + df_3['IAA_2021']*0.1 + df_3['IPS_2021']*0.1 + df_3['IPP_2021']*0.1 + df_3['IPV_2021']*0.2,
    df_3['IAN_2021']*0.1 + df_3['IDA_2021']*0.4 + df_3['IEG_2021']*0.2 + df_3['IAA_2021']*0.1 + df_3['IPS_2021']*0.2
)

df_3['INDE_CALCULADO_2022'] = np.where(
    df_3['FASE_2022'] < 8,
    df_3['IAN_2022']*0.1 + df_3['IDA_2022']*0.2 + df_3['IEG_2022']*0.2 + df_3['IAA_2022']*0.1 + df_3['IPS_2022']*0.1 + df_3['IPP_2022']*0.1 + df_3['IPV_2022']*0.2,
    df_3['IAN_2022']*0.1 + df_3['IDA_2022']*0.4 + df_3['IEG_2022']*0.2 + df_3['IAA_2022']*0.1 + df_3['IPS_2022']*0.2
)

df_3.head()
# Out:
#       NOME  ANOS_PM_2020  FASE_TURMA_2020  FASE_2021  FASE_2022  IAA_2020  \
# 0  ALUNO-1           2.0              2.0        2.0        NaN       NaN
# 1  ALUNO-2           NaN              NaN        NaN        0.0       NaN
# 2  ALUNO-3           2.0              3.0        3.0        NaN   791.667
# 3  ALUNO-4           2.0              1.0        NaN        2.0       NaN
# 4  ALUNO-5           1.0              2.0        2.0        2.0   750.002
#
#    IAA_2021  IAA_2022  IAN_2020  IAN_2021  IAN_2022  IDA_2020  IDA_2021  \
# 0       7.5       NaN      10.0       5.0       NaN       7.0       8.8
# 1       NaN       NaN       NaN       NaN       5.0       NaN       NaN
# 2       7.1       NaN      10.0      10.0       NaN       5.5       5.6
# 3       NaN       NaN       5.0       NaN       5.0       0.0       NaN
# 4       7.4   641.668      10.0      10.0       5.0       7.5       5.4
#
#    IDA_2022  IEG_2020  IEG_2021  IEG_2022  INDE_2020  INDE_2021  INDE_2022  \
# ...

# %%
df_3.isnull().sum()
# Out:
# NOME                      0
# ANOS_PM_2020            622
# FASE_TURMA_2020         622
# FASE_2021               663
# FASE_2022               487
# IAA_2020               1019
# IAA_2021                663
# IAA_2022                862
# IAN_2020                622
# IAN_2021                663
# IAN_2022                487
# IDA_2020                806
# IDA_2021                663
# IDA_2022               1024
# IEG_2020                622
# IEG_2021                663
# IEG_2022               1291
# INDE_2020              1330
# INDE_2021               665
# INDE_2022              1348
# IPP_2020                863
# IPP_2021                663
# IPP_2022                695
# IPS_2020                622
# IPS_2021                663
# IPS_2022                487
# IPV_2020               1101
# IPV_2021                663
# IPV_2022               1095
# PEDRA_2020              621
# PEDRA_2021              663
# PEDRA_2022              487
# PONTO_VIRADA_2020       647
# ...
